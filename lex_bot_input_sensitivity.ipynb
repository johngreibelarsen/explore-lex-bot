# %%
from IPython.display import display, HTML
import pandas as pd

df = pd.read_excel (r'./tests/ChangePersonalDetails-V1.2.xls')

print(df.columns)

display(df.head(5))
# Out:
# Index(['User', 'Bot'], dtype='object')
#                                                 User  \
# 0          I need to update my personal information
# 1                 Can I make a change to my profile?
# 2  How do I amend the personal information you ho...
# 3          Tell me how to update my contact details
# 4  Who do I need to call and what do I need to up...
#
#                                                  Bot
# 0  What personal information would you like to up...
# 1  What personal information would you like to up...
# 2  What personal information would you like to up...
# 3  What personal information would you like to up...
# 4  What personal information would you like to up...

# %%
results = [(input, output) for input, output in zip(df['User'], df['Bot'])]

for entry in results:
    print(entry)
# Out:
# ('I need to update my personal information ', 'What personal information would you like to update?')
# ('Can I make a change to my profile?', 'What personal information would you like to update?')
# ('How do I amend the personal information you hold on me?', 'What personal information would you like to update?')
# ('Tell me how to update my contact details ', 'What personal information would you like to update?')
# ('Who do I need to call and what do I need to update you about myself?', 'What personal information would you like to update?')
# ('How can I update my personal details?', 'What personal information would you like to update?')
# ('Want to update my profile.', 'What personal information would you like to update?')
# ('Help me changing my details please.', 'What personal information would you like to update?')
# ('Is it possible to change my personal details with you?', 'What personal information would you like to update?')
# ...
