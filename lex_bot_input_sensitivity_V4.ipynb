# %% [markdown]
# ### Let's build a Panda dataframe with all test data

# %% [markdown]
# #### Response codes and response messages

# %%
#pip install --user matplotlib==3.1.0

# %%
from IPython.display import display, HTML
import matplotlib.pyplot as plt
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

df_codes_and_responses = pd.read_excel (r'./tests/CaptainServiceRegressionPack/Codes_Responses_modified.xls')
display(df_codes_and_responses.head(50))
# Out:
#            Competency Intent response Response_ID  \
# 0               Fraud    csbFraudROne    FRAUD_R1
# 1               Fraud    csbFraudRTwo    FRAUD_R2
# 2               Fraud  csbFraudRThree    FRAUD_R3
# 3            PinQuery     csbPinQrOne    PIN_Q_R1
# 4            PinQuery     csbPinQrTwo    PIN_Q_R2
# 5                 OOS      csbOosROne      OOS_R1
# 6                 OOS    CsbOosROne_1    OOS_R1_1
# 7                 CPD      csbCpdROne      CPD_R1
# 8                 CPD      csbCpdRTwo      CPD_R2
# 9                 CPD    csbCpdRThree      CPD_R3
# 10                CPD     csbCpdRFour      CPD_R4
# 11                CPD     csbCpdRFive      CPD_R5
# 12                CPD      csbCpdRSix      CPD_R6
# 13                CPD    csbCpdRSeven      CPD_R7
# 14                CPD    csbCpdREight      CPD_R8
# 15                CPD     csbCpdRNine      CPD_R9
# 16                CPD      csbCpdRTen     CPD_R10
# 17          Overdraft       csbOdROne       OD_R1
# 18          Overdraft     csbOdROne_1     OD_R1_1
# 19          Overdraft       csbOdRTwo       OD_R2
# 20          Overdraft     csbOdRTwo_1     OD_R2_1
# 21          Overdraft     csbOdRThree       OD_R3
# 22        Bereavement      csbBerROne      BER_R1
# 23         ManageCard     csbCrdIROne       MC_R1
# 24         ManageCard     csbCrdIRTwo       MC_R2
# 25         ManageCard   csbCrdIRThree       MC_R3
# 26         ManageCard    csbCrdIRFour       MC_R4
# 27         ManageCard    csbCrdIRFive       MC_R5
# 28       BankTransfer        csbBtOne       BT_R1
# 29       CardPayments      csbBcpROne       CP_R1
# 30       CardPayments      csbBcpRTwo       CP_R2
# 31       CardPayments    csbBcpRThree       CP_R3
# 32       CardPayments     csbBcpRFour       CP_R4
# 33       CardPayments     csbBcpRFive       CP_R5
# 34       CardPayments      csbBcpRSix       CP_R6
# 35       CardPayments    csbBcpRSeven       CP_R7
# 36  DuplicatePayments      csbDpsROne       DP_R1
# 37  DuplicatePayments      csbDpsRTwo       DP_R2
# 38  DuplicatePayments    csbDpsRThree       DP_R3
# 39  DuplicatePayments     csbDpsRFour       DP_R4
# 40       Transactions      csbTraROne       TR_R1
# 41       Transactions      csbTraRTwo       TR_R2
# 42       Transactions    csbTraRThree       TR_R3
# 43      PaymentStatus      csbPayROne       PS_R1
# 44      PaymentStatus      csbPayRTwo       PS_R2
# 45      PaymentStatus    csbPayRThree       PS_R3
# 46      PaymentStatus     csbPayRFour       PS_R4
# 47            Closing      csbClsROne       CL_R1
# 48           Handover       csbHoROne       HO_R1
# 49           Handover     csbHoROne_1     HO_R1_1
#
#                                              Response
# 0   Okay, so I can make sure you speak to the righ...
# 1   I know it can be worrying if you think there's...
# 2   I know it can be worrying if you think there's...
# 3   The PIN for your new card will be the same as ...
# 4   I'm sorry to read your PIN hasn't arrived yet....
# 5   could you try to rephrase your query for me? <...
# 6   I still don't understand your query. I've plac...
# 7   What personal information would you like to up...
# 8   To change your name, you'll need to visit us i...
# 9   If we do not have your correct date of birth y...
# 10  Most customers can update their address in the...
# 11  To update your nationality, you'll need to vis...
# 12  To update your country of birth you'll need to...
# 13  You can update your income and employment stat...
# 14  You can update your email address in the app b...
# 15  You can update your phone number(s) in the app...
# 16  You can manage many parts of your personal inf...
# 17  Great news, I can see that you have a provisio...
# 18  I'm sorry, but at the moment you're not eligib...
# 19  You can increase your overdraft of £100 up to ...
# 20  You currently have the maximum overdraft limit...
# 21  To reduce your overdraft or stop it entirely, ...
# 22  Dealing with the financial affairs of someone ...
# 23  I'm sorry that you think your card is lost.<br...
# 24  I'm sorry that your card was stolen. The quick...
# 25  I'm sorry that your card is damaged.<br> You c...
# 26  You can apply a temporary freeze to your card ...
# 27  You can add your Barclays debit card or Barcla...
# 28  If you've paid a person or business by bank tr...
# 29  To make a debit card payment towards your Barc...
# 30  To set up a Direct Debit for your Barclaycard,...
# 31  What do you need to update for your Barclaycar...
# 32  You can change the amount you pay towards your...
# 33  If your bank details have changed, you can upd...
# 34  Are you sure you want to cancel your Barclayca...
# 35  You can make multiple, smaller payments toward...
# 36  You'll need to speak to one of my colleagues a...
# 37  I'll connect you with one of my human colleagu...
# 38  You can call us at the number below to discuss...
# 39  One of our branch colleagues will happily look...
# 40  A pending transaction is an authorised payment...
# 41  If something looks wrong with a pending transa...
# 42  If you've had a problem with an item or servic...
# 43  You can check the status of a payment you have...
# 44  I'll connect you with one of my human colleagu...
# 45  You can call us on the number below to discuss...
# 46  One of our branch colleagues will happily look...
# 47                   I'm glad I could help you today,
# 48  I can connect you to one of my human colleague...
# 49    I'll connect you with one of my colleagues now.

# %%
def found_match(short_str, long_str):
    short_str = pre_process_string(short_str)
    long_str = pre_process_string(long_str.values[0])
    return long_str.startswith(short_str)

def pre_process_response(string):
    temp = string.strip()
    temp = temp.replace('\n', '')
    temp = temp.replace('\t', '')
    temp = temp.replace('"', '')
    temp = temp.replace("'", '')
    temp = temp.replace("’", '')
    temp = temp.replace("‘", '')
    
    return temp

def pre_process_intent_code(string):
    temp = string.strip()
    temp = temp.lower()
    temp = temp.replace('\t', '')
    temp = temp.replace(' ', '')
    
    return temp

# %%
df_codes_and_responses['Response'] = df_codes_and_responses.apply(lambda x: pre_process_response(x['Response']), axis=1)
df_codes_and_responses['Intent response'] = df_codes_and_responses.apply(lambda x: pre_process_intent_code(x['Intent response']), axis=1)

# %%
df_codes_and_responses.head(5)
# Out:
#   Competency Intent response Response_ID  \
# 0      Fraud    csbfraudrone    FRAUD_R1
# 1      Fraud    csbfraudrtwo    FRAUD_R2
# 2      Fraud  csbfraudrthree    FRAUD_R3
# 3   PinQuery     csbpinqrone    PIN_Q_R1
# 4   PinQuery     csbpinqrtwo    PIN_Q_R2
#
#                                             Response
# 0  Okay, so I can make sure you speak to the righ...
# 1  I know it can be worrying if you think theres ...
# 2  I know it can be worrying if you think theres ...
# 3  The PIN for your new card will be the same as ...
# 4  Im sorry to read your PIN hasnt arrived yet.<b...

# %%
def get_response_msg(intent_code):
    row = df_codes_and_responses.loc[df_codes_and_responses['Intent response'] == pre_process_intent_code(intent_code)]
    return row['Response_ID'].values[0], row['Response'].values[0]

# %%
response_id, response_msg = get_response_msg('csbPinQrOne')
print(response_id)
print('------------------------------------------')
print(response_msg)
# Out:
# PIN_Q_R1
# ------------------------------------------
# The PIN for your new card will be the same as your old one, unless you reported your old card lost or stolen and asked for a new PIN.<br>If you did, a new PIN will be sent to you in the post separately to the card.

# %%
def get_competency(intent_code):
    intent_code = pre_process_intent_code(intent_code)
    df = df_codes_and_responses.loc[df_codes_and_responses['Intent response'] == intent_code]
    return df.Competency.unique()

# %%
competency_list = get_competency('csbPinQrOne')
print(competency_list)
# Out:
# ['PinQuery']

# %%
def get_response_intent_codes(response_msg):
    pre_response_msg = pre_process_response(response_msg)
    for index, row in df_codes_and_responses.iterrows():
        if row['Response'] in pre_response_msg:
            return row['Intent response'], row['Response_ID']
    return  '*', '*'

# %%
intent_code, response_id = get_response_intent_codes(
    '''Dealing with the financial affairs of someone close to you when you're grieving is never easy.<br>I'll place you in the queue to chat with a member of our bereavement team as soon as they become available.''')
print(intent_code)
print('------------------------------------------')
print(response_id)
# Out:
# csbberrone
# ------------------------------------------
# BER_R1

# %% [markdown]
# #### Building the test-suit

# %%
import boto3
import uuid
uid = str(uuid.uuid4())
client = boto3.client('lex-runtime', aws_access_key_id='', aws_secret_access_key='', region_name="eu-central-1") ## eu-west-2

# %%
df_bcp = pd.read_excel (r'./tests/CaptainServiceRegressionPack/BarclaycardPayments_TestSuit.xls')
df_ber = pd.read_excel (r'./tests/CaptainServiceRegressionPack/BereavementTestSuit-V3.xlsx')
df_btr = pd.read_excel (r'./tests/CaptainServiceRegressionPack/BankTransfer_TestSuit.xls')
df_cls = pd.read_excel (r'./tests/CaptainServiceRegressionPack/Closing_TestSuit.xls')
df_cpd = pd.read_excel (r'./tests/CaptainServiceRegressionPack/ChangePersonalDetails-V1.2.xls')
df_dps = pd.read_excel (r'./tests/CaptainServiceRegressionPack/DuplicatePayments_TestSuit.xls')
df_frd = pd.read_excel (r'./tests/CaptainServiceRegressionPack/Fraud_Scoping_TestSuit-V1.1.xls')
df_hao = pd.read_excel (r'./tests/CaptainServiceRegressionPack/Handover_TestSuit.xls')
df_mcd = pd.read_excel (r'./tests/CaptainServiceRegressionPack/ManageCards_TestSuit.xls')
df_oos = pd.read_excel (r'./tests/CaptainServiceRegressionPack/Out_Of_Scope_TestSuit-V3.xls')
df_ove = pd.read_excel (r'./tests/CaptainServiceRegressionPack/OverdraftTestSuit-V12.xlsx')
df_pay = pd.read_excel (r'./tests/CaptainServiceRegressionPack/PaymentStatus_TestSuit.xls')
df_piq = pd.read_excel (r'./tests/CaptainServiceRegressionPack/PINQuery_TestSuit.xls')
df_tra = pd.read_excel (r'./tests/CaptainServiceRegressionPack/Transactions_TestSuit.xls')

# %%
# to be deleted
df_test_suit = df_bcp.append(df_ber)
df_test_suit = df_test_suit.append(df_btr)
df_test_suit = df_test_suit.append(df_cls)
df_test_suit = df_test_suit.append(df_cpd)
df_test_suit = df_test_suit.append(df_dps)
df_test_suit = df_test_suit.append(df_frd)
df_test_suit = df_test_suit.append(df_hao)
df_test_suit = df_test_suit.append(df_mcd)
df_test_suit = df_test_suit.append(df_oos)
df_test_suit = df_test_suit.append(df_ove)
df_test_suit = df_test_suit.append(df_pay)
df_test_suit = df_test_suit.append(df_piq)
df_test_suit = df_test_suit.append(df_tra)

print(df_test_suit.shape[0])
# Out:
# 1372

# %%
df_test_suit = df_bcp.append(df_ber)
df_test_suit = df_test_suit.append(df_btr)
df_test_suit = df_test_suit.append(df_cpd)
df_test_suit = df_test_suit.append(df_frd)
df_test_suit = df_test_suit.append(df_oos)
#df_test_suit = df_test_suit.append(df_ove)
#df_test_suit = df_test_suit.append(df_piq)

print(df_test_suit.shape[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-9fa8fb313157> in <module>
# ----> 1 df_test_suit = df_bcp.append(df_ber)
#       2 df_test_suit = df_test_suit.append(df_btr)
#       3 df_test_suit = df_test_suit.append(df_cpd)
#       4 df_test_suit = df_test_suit.append(df_frd)
#       5 df_test_suit = df_test_suit.append(df_oos)
#
# NameError: name 'df_bcp' is not defined

# %%
df_test_suit = df_test_suit.dropna(axis=0, how='any')

print(df_test_suit.shape[0])
# Out:
# 1372

# %%
df_test_suit.rename(columns={"Bot": "Expected intent code"}, inplace=True)

# %%
df_test_suit['Expected competency'] = ''
df_test_suit['Expected response ID'] = ''
df_test_suit['Actual response'] = ''
df_test_suit['Actual competency'] = ''
df_test_suit['Actual intent code'] = ''
df_test_suit['Actual response ID'] = ''
df_test_suit.reset_index(drop=True, inplace=True)

Column_order = ['User',
 'Expected competency',
 'Expected intent code',
 'Expected response ID',
 'Actual response',
 'Actual competency',
 'Actual intent code',
 'Actual response ID']

df_test_suit = df_test_suit[Column_order]

df_test_suit[100:110].head(3)
# Out:
#                                                   User Expected competency  \
# 100  Hi,today I been to Harrow branch to update my ...
# 101  What is the process of upgrading a pre existin...
# 102  Hey! Guide me through in making changes to my ...
#
#     Expected intent code Expected response ID Actual response  \
# 100  INTENT csbBcpRThree
# 101  INTENT csbBcpRThree
# 102  INTENT csbBcpRThree
#
#     Actual competency Actual intent code Actual response ID
# 100
# 101
# 102

# %%
def remove_intent(bot_intent):
    if 'INTENT ' in str(bot_intent):
        bot_intent = bot_intent.replace('INTENT ', '')
    return pre_process_intent_code(bot_intent)

df_test_suit['Expected intent code'] = df_test_suit.apply(lambda x: remove_intent(x['Expected intent code']), axis=1)

# %%
def add_competency(bot_intent):
    bot_intent = pre_process_intent_code(bot_intent)
    return get_competency(bot_intent)[0]

df_test_suit['Expected competency'] = df_test_suit.apply(lambda x: add_competency(x['Expected intent code']), axis=1)

# %%
df_test_suit[100:140].head(3)
# Out:
#                                                   User Expected competency  \
# 100  Hi,today I been to Harrow branch to update my ...        CardPayments
# 101  What is the process of upgrading a pre existin...        CardPayments
# 102  Hey! Guide me through in making changes to my ...        CardPayments
#
#     Expected intent code Expected response ID Actual response  \
# 100         csbbcprthree
# 101         csbbcprthree
# 102         csbbcprthree
#
#     Actual competency Actual intent code Actual response ID
# 100
# 101
# 102

# %% [markdown]
# #### Getting responses from the bot

# %%
response = client.post_text(botName='CptServiceBot', botAlias='Live', userId=uid, inputText="Can branch staff look into why payments I know were made haven't arrived?")
response['message']

# %%
for index, row in df_test_suit.iterrows():
    question = row['User']
    response = client.post_text(botName='CptServiceBot', botAlias='Live', userId=uid, inputText=question)
    if index % 100 == 0:
        print(index)    
    response_str = pre_process_response(response['message'])
    df_test_suit.iat[index, 4] = response_str 
    intent_code, _ = get_response_intent_codes(response_str)
    competency = get_competency(intent_code)
    if not competency:
        competency = 'None'
    else:
        competency = competency[0]
    df_test_suit.iat[index, 5] = competency
    df_test_suit.iat[index, 6] = intent_code
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300

# %%
display(df_test_suit[100:150].head(5))
# Out:
#                                                   User Expected competency  \
# 100  Hi,today I been to Harrow branch to update my ...        CardPayments
# 101  What is the process of upgrading a pre existin...        CardPayments
# 102  Hey! Guide me through in making changes to my ...        CardPayments
# 103  How can I amend my pre authorised debit used t...        CardPayments
# 104  I wish to edit my automated payments used for ...        CardPayments
#
#     Expected intent code Expected response ID  \
# 100         csbbcprthree
# 101         csbbcprthree
# 102         csbbcprthree
# 103         csbbcprthree
# 104         csbbcprthree
#
#                                        Actual response Actual competency  \
# 100  What do you need to update for your Barclaycar...      CardPayments
# 101  What do you need to update for your Barclaycar...      CardPayments
# 102  What do you need to update for your Barclaycar...      CardPayments
# 103  What do you need to update for your Barclaycar...      CardPayments
# 104  What do you need to update for your Barclaycar...      CardPayments
#
#     Actual intent code Actual response ID
# 100       csbbcprthree
# 101       csbbcprthree
# 102       csbbcprthree
# 103       csbbcprthree
# 104       csbbcprthree

# %%
def extract_main_intent(intent):
    index = intent.find('_')
    if index != -1:
        return intent[:index]
    return intent

df_test_suit['Actual intent code'] = df_test_suit.apply(lambda x: extract_main_intent(x['Actual intent code']), axis=1)

# %%
display(df_test_suit[100:150].head(5))
# Out:
#                                                   User Expected competency  \
# 100  Hi,today I been to Harrow branch to update my ...        CardPayments
# 101  What is the process of upgrading a pre existin...        CardPayments
# 102  Hey! Guide me through in making changes to my ...        CardPayments
# 103  How can I amend my pre authorised debit used t...        CardPayments
# 104  I wish to edit my automated payments used for ...        CardPayments
#
#     Expected intent code Expected response ID  \
# 100         csbbcprthree
# 101         csbbcprthree
# 102         csbbcprthree
# 103         csbbcprthree
# 104         csbbcprthree
#
#                                        Actual response Actual competency  \
# 100  What do you need to update for your Barclaycar...      CardPayments
# 101  What do you need to update for your Barclaycar...      CardPayments
# 102  What do you need to update for your Barclaycar...      CardPayments
# 103  What do you need to update for your Barclaycar...      CardPayments
# 104  What do you need to update for your Barclaycar...      CardPayments
#
#     Actual intent code Actual response ID
# 100       csbbcprthree
# 101       csbbcprthree
# 102       csbbcprthree
# 103       csbbcprthree
# 104       csbbcprthree

# %% [markdown]
# ### Confusion Matrix and Statistics per Competency

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

def cm_analysis(y_true, y_pred, labels=None, ymap=None, figsize=(10,10)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels = [ymap[yi] for yi in labels]
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm_perc, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax, cmap="Blues")
    plt.figure(figsize=(20,10))
    plt.show()

cm_analysis(df_test_suit['Expected competency'], df_test_suit['Actual competency'], labels=['BankTransfer','Bereavement','CardPayments','Closing','CPD','DuplicatePayments','Fraud','Handover','ManageCard','OOS', 'Overdraft', 'PaymentStatus','PinQuery','Transactions','None'], figsize=(15,10))
##cm_analysis(df_test_suit['Expected competency'], df_test_suit['Actual competency'], labels=['Bereavement', 'CPD', 'OOS', 'Overdraft'], figsize=(15,10))

# %%
from pandas_ml import ConfusionMatrix

confusion_matrix = ConfusionMatrix(df_test_suit['Expected competency'], df_test_suit['Actual competency'])

# %%
stats_class= confusion_matrix.stats()['class']

# %%
# Drop column
#stats_class.drop('*', inplace=True, axis=1)

# %%
from collections import Counter

# Drop rows
all_rows = list(stats_class.index.values)
keep_rows = ['TP: True Positive', 'TN: True Negative', 'FP: False Positive', 'FN: False Negative', 'TPR: (Sensitivity, hit rate, recall)', 'TNR=SPC: (Specificity)', 'ACC: Accuracy', 'F1 score']
remove_rows = list((Counter(all_rows)-Counter(keep_rows)).elements()) 
stats_class.drop(remove_rows, inplace=True, axis=0)

# %%
stats_class
# Out:
# Classes                              BankTransfer       CPD CardPayments  \
# TP: True Positive                               0         0            0
# TN: True Negative                             507       507          507
# FP: False Positive                              1         1            1
# FN: False Negative                              0         0            0
# TPR: (Sensitivity, hit rate, recall)          NaN       NaN          NaN
# TNR=SPC: (Specificity)                   0.998031  0.998031     0.998031
# ACC: Accuracy                            0.998031  0.998031     0.998031
# F1 score                                        0         0            0
#
# Classes                                Closing DuplicatePayments     Fraud  \
# TP: True Positive                           59                93         0
# TN: True Negative                          447               412       507
# FP: False Positive                           1                 0         1
# FN: False Negative                           1                 3         0
# TPR: (Sensitivity, hit rate, recall)  0.983333           0.96875       NaN
# TNR=SPC: (Specificity)                0.997768                 1  0.998031
# ACC: Accuracy                         0.996063          0.994094  0.998031
# F1 score                              0.983333          0.984127         0
#
# Classes                               Handover ManageCard       OOS  \
# TP: True Positive                           39        102         0
# TN: True Negative                          468        403       505
# FP: False Positive                           0          0         3
# FN: False Negative                           1          3         0
# TPR: (Sensitivity, hit rate, recall)     0.975   0.971429       NaN
# TNR=SPC: (Specificity)                       1          1  0.994094
# ACC: Accuracy                         0.998031   0.994094  0.994094
# F1 score                              0.987342   0.985507         0
#
# Classes                              PaymentStatus Transactions
# TP: True Positive                               97          109
# TN: True Negative                              411          397
# FP: False Positive                               0            1
# FN: False Negative                               0            1
# TPR: (Sensitivity, hit rate, recall)             1     0.990909
# TNR=SPC: (Specificity)                           1     0.997487
# ACC: Accuracy                                    1     0.996063
# F1 score                                         1     0.990909

# %% [markdown]
# Precision=tp/(tp+fp)
# <BR>
# Recall=tp/(tp+fn)

# %%
stats_class[['Bereavement', 'CPD', 'OOS', 'Overdraft']]

# %%
stats_summed = stats_class.sum(axis=1)
tp = stats_summed[0]
fp = stats_summed[2]
fn = stats_summed[3]

precision = tp/(tp+fp)
recall = tp/(tp+fn)

print(f'Total Precision = {precision}')
print(f'Total Recall = {recall}')

# %% [markdown]
# ### Confusion Matrix and Statistics per Intent

# %%
intent_labels = sorted(df_codes_and_responses['Intent response'].unique())

# %%
#cm_analysis(df_test_suit['Expected intent code'], df_test_suit['Actual intent code'], labels=['csbberrone','csbcpdrone','csbcpdrtwo','csbcpdrthree','csbcpdrfour','csbcpdrfive','csbcpdrsix','csbcpdrseven','csbcpdreight','csbcpdrnine','csbcpdrten','csbfraudrone','csbodrone','csbodrtwo','csbodrthree','csboosrone','csboosrtwo','csbpinqrone','csbpinqrtwo'], figsize=(15,10))
cm_analysis(df_test_suit['Expected intent code'], df_test_suit['Actual intent code'], labels=intent_labels, figsize=(25,14))

# %%
confusion_matrix_intents = ConfusionMatrix(df_test_suit['Expected intent code'], df_test_suit['Actual intent code'])

# %%
stats_class_intents = confusion_matrix_intents.stats()['class']

# %%
# Drop rows
all_rows = list(stats_class_intents.index.values)
keep_rows = ['TP: True Positive', 'TN: True Negative', 'FP: False Positive', 'FN: False Negative', 'TPR: (Sensitivity, hit rate, recall)', 'TNR=SPC: (Specificity)', 'ACC: Accuracy', 'F1 score']
remove_rows = list((Counter(all_rows)-Counter(keep_rows)).elements()) 
stats_class_intents.drop(remove_rows, inplace=True, axis=0)

# %%
stats_class_intents
